# %%
import requests
import json
import os.path

# %%
def getType(this):
    """ This function returns the two digit type of the game depending on the user's input. 
        The default game type is regular (02).
    """
    if this.lower()   == 'preseason':
        return(str(1).zfill(2))
    elif this.lower() == 'regular':
        return(str(2).zfill(2))
    elif this.lower() == 'playoffs':
        return(str(3).zfill(2))
    elif this.lower() == 'all-star':
        return(str(4).zfill(2))
    else:
        return(str(2).zfill(2))

# %%
def stats(gameId):
    """ Given the string gameId, this fucntion will check if the JSON response of the API call of that gameId already exists.
        If the filepath exists, it will read it. If the filepath does not exist, it will call the REST API and download the JSON response. 
        The file will be named playbyplay_ followed by the unique gameId.
    """
    API_URL = "https://statsapi.web.nhl.com/api/v1"
    path = "./playbyplay_" + str(gameId) + ".json" 
    check_file = os.path.isfile(path)
    if check_file:
        with open(path, 'r') as f:
            data = json.load(f)
    else:
        response = requests.get(API_URL + "/game/" + str(gameId) + "/feed/live/", params={"Content-Type": "application/json"})
        data = response.json()
        with open(path, "w") as f:
            json.dump(data, f)

# %%
def play_by_play(year, type):
    """ The unofficial NHL API Documentation states that there were 1230 games per season before 2017, 1271 games per season after 2017, and 1353 games per season after 2022. 
        The number of games played each season will determine the range of i. 
        Given the year and type of the game, this function will call the getType function and build the gameId string. 
        Then it will call the stats function for every game of that season (0001 to 1271).
    """
    if year <= 2016:
        for i in range(1,1231):
            gameId = str(year) + str(getType(type)) + str(i).zfill(4)
            stats(gameId)
    elif 2017 <= year <= 2021:
        for i in range(1,1272):
            gameId = str(year) + str(getType(type)) + str(i).zfill(4)
            stats(gameId)
    else:
        for i in range(1,1354):
            gameId = str(year) + str(getType(type)) + str(i).zfill(4)
            stats(gameId)

# %%
play_by_play(2016, 'regular')

# %%
play_by_play(2017, 'regular')

# %%
play_by_play(2018, 'regular')

# %%
play_by_play(2019, 'regular')

# %%
play_by_play(2020, 'regular')

# %%
def play_by_play_specific(year, type, game):
    """ This fucntion will call the stats function for a specific game of the season.
    """
    gameId = str(year) + str(getType(type)) + str(game).zfill(4)
    stats(gameId)

# %%
# Since there is not a definitive number of macthups in the documentation. We called the Records API to get the gameId's of all playoffs. 
z =  requests.get("https://records.nhl.com/site/api/playoff-series?")
records = z.json()
print(records)
# Out:
# {'data': [{'id': 1614, 'bottomSeedWins': 0, 'gameId': 1993030111, 'gameNumber': 111, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'A', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 1}, {'id': 1615, 'bottomSeedWins': 0, 'gameId': 1993030112, 'gameNumber': 112, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'A', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 2}, {'id': 1616, 'bottomSeedWins': 0, 'gameId': 1993030113, 'gameNumber': 113, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'A', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 3}, {'id': 1617, 'bottomSeedWins': 0, 'gameId': 1993030114, 'gameNumber': 114, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'A', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 4}, {'id': 1618, 'bottomSeedWins': 1, 'gameId': 1993030121, 'gameNumber': 121, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'B', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 0}, {'id': 1619, 'bottomSeedWins': 1, 'gameId': 1993030122, 'gameNumber': 122, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'B', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 1}, {'id': 1620, 'bottomSeedWins': 2, 'gameId': 1993030123, 'gameNumber': 123, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'B', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 1}, {'id': 1621, 'bottomSeedWins': 3, 'gameId': 1993030124, 'gameNumber': 124, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'B', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 1}, {'id': 1622, 'bottomSeedWins': 3, 'gameId': 1993030125, 'gameNumber': 125, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'B', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 2}, {'id': 1623, 'bottomSeedWins': 4, 'gameId': 1993030126, 'gameNumber': 126, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'B', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 2}, {'id': 1624, 'bottomSeedWins': 1, 'gameId': 1993030131, 'gameNumber': 131, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'C', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 0}, {'id': 1625, 'bottomSeedWins': 1, 'gameId': 1993030132, 'gameNumber': 132, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'C', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 1}, {'id': 1626, 'bottomSeedWins': 1, 'gameId': 1993030133, 'gameNumber': 133, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'C', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 2}, {'id': 1627, 'bottomSeedWins': 2, 'gameId': 1993030134, 'gameNumber': 134, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'C', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'topSeedWins': 2}, {'id': 1628, 'bottomSeedWins': 2, 'gameId': 1993030135, 'gameNumber': 135, 'gameTypeId': 3, 'gamesNeededToWin': 4, 'lengthOfSeries': 7, 'playoffRound': 1, 'playoffSeriesLetter': 'C', 'seasonId': 19931994, 'seriesTitle': 'Conference Quarterfinals', 'top ...

# %%
# Filer the response of the Records API to obtain the gameId's of all playoffs between seasons 2016-2017 and 2020-2021. Created an array called "gameIds". 
# We validated that they all have type id '03'
gameIds = [game["gameId"] for game in records["data"] if 
           game["seasonId"] ==20162017 
           or game["seasonId"]==20172018 
           or game["seasonId"]==20182019
           or game["seasonId"]==20192020
           or game["seasonId"]==20202021]
print(gameIds)
# Out:
# [2016030111, 2016030112, 2016030113, 2016030114, 2016030115, 2016030116, 2016030121, 2016030122, 2016030123, 2016030124, 2016030125, 2016030126, 2016030131, 2016030132, 2016030133, 2016030134, 2016030135, 2016030136, 2016030141, 2016030142, 2016030143, 2016030144, 2016030145, 2016030151, 2016030152, 2016030153, 2016030154, 2016030161, 2016030162, 2016030163, 2016030164, 2016030165, 2016030171, 2016030172, 2016030173, 2016030174, 2016030181, 2016030182, 2016030183, 2016030184, 2016030185, 2016030186, 2016030211, 2016030212, 2016030213, 2016030214, 2016030215, 2016030216, 2016030221, 2016030222, 2016030223, 2016030224, 2016030225, 2016030226, 2016030227, 2016030231, 2016030232, 2016030233, 2016030234, 2016030235, 2016030236, 2016030241, 2016030242, 2016030243, 2016030244, 2016030245, 2016030246, 2016030247, 2016030311, 2016030312, 2016030313, 2016030314, 2016030315, 2016030316, 2016030317, 2016030321, 2016030322, 2016030323, 2016030324, 2016030325, 2016030326, 2016030411, 2016030412, 2016030413, 2016030414, 2016030415, 2016030416, 2017030111, 2017030112, 2017030113, 2017030114, 2017030115, 2017030121, 2017030122, 2017030123, 2017030124, 2017030125, 2017030126, 2017030127, 2017030131, 2017030132, 2017030133, 2017030134, 2017030135, 2017030136, 2017030141, 2017030142, 2017030143, 2017030144, 2017030145, 2017030146, 2017030151, 2017030152, 2017030153, 2017030154, 2017030155, 2017030156, 2017030161, 2017030162, 2017030163, 2017030164, 2017030165, 2017030171, 2017030172, 2017030173, 2017030174, 2017030181, 2017030182, 2017030183, 2017030184, 2017030211, 2017030212, 2017030213, 2017030214, 2017030215, 2017030221, 2017030222, 2017030223, 2017030224, 2017030225, 2017030226, 2017030231, 2017030232, 2017030233, 2017030234, 2017030235, 2017030236, 2017030237, 2017030241, 2017030242, 2017030243, 2017030244, 2017030245, 2017030246, 2017030311, 2017030312, 2017030313, 2017030314, 2017030315, 2017030316, 2017030317, 2017030321, 2017030322, 2017030323, 2017030324, 2017030325, 2017030411, 2017030412, 2017030413, 2017030414, 2017030415, 2018030137, 2018030211, 2018030231, 2018030241, 2018030111, 2018030112, 2018030113, 2018030114, 2018030121, 2018030122, 2018030123, 2018030124, 2018030125, 2018030126, 2018030127, 2018030131, 2018030132, 2018030133, 2018030134, 2018030135, 2018030136, 2018030141, 2018030142, 2018030143, 2018030144, 2018030151, 2018030152, 2018030153, 2018030154, 2018030155, 2018030156, 2018030161, 2018030162, 2018030163, 2018030164, 2018030165, 2018030166, 2018030171, 2018030172, 2018030173, 2018030174, 2018030175, 2018030181, 2018030182, 2018030183, 2018030184, 2018030185, 2018030186, 2018030187, 2018030212, 2018030213, 2018030214, 2018030215, 2018030216, 2018030221, 2018030222, 2018030223, 2018030224, 2018030232, 2018030233, 2018030234, 2018030235, 2018030236, 2018030237, 2018030242, 2018030243, 2018030244, 2018030245, 2018030246, 2018030247, 2018030311, 2018030312, 2018030313, 2018030314, 2018030321, 2018030322, 2018030323, 2018030324, 2018030325, 2018030326, 2018030411, 2018030412, 2018030413, 2018030414, 2018030415, 2018030416, 2018030417, 2019030021, 2019030022, 2019030023, 2019030024, 2019030031, 2019030032, 2019030033, 2019030041, 2019030042, 2019030043, 2019030044, 2019030051, 2019030052, 2019030053, 2019030054, 2019030055, 2019030061, 2019030062, 2019030063, 2019030064, 2019030071, 2019030072, 2019030073, 2019030074, 2019030081, 2019030082, 2019030083, 2019030084, 2019030091, 2019030092, 2019030093, 2019030094, 2019030111, 2019030112, 2019030113, 2019030114, 2019030115, 2019030116, 2019030121, 2019030122, 2019030123, 2019030124, 2019030125, 2019030131, 2019030132, 2019030133, 2019030134, 2019030135, 2019030141, 2019030142, 2019030143, 2019030144, 2019030145, 2019030151, 2019030152, 2019030153, 2019030154, 2019030155, 2019030161, 2019030162, 2019030163, 2019030164, 2019030165, 2019030171, 2019030172, 2019030173, 2019030174, 2019030175, 2019030176, 2019030181, 2019030182, 2019030183, 2019030184, 2019030185, 2019030186, 201 ...

# %%
#The stats function will be called for each playoff gameId obtained from the array "gameIds"
for playOffGameId in gameIds:
    stats(playOffGameId)
